# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AzizKABA/pythonCodeChallenges/blob/main/Beginner/_8_typingTextEffect.ipynb)

# %% [markdown]
# # Python Code Challenges
#
# Challenge Question Source: 101computing.net
#
# Level: Beginner
#
# Solutions: by Aziz KABA
#
# TimeStamp : 16/08/2022
# 22:45

# %% [markdown]
# ## **Python Typing Text Effect**

# %% [markdown]
# In this blog post we will revisit two of the key python functions: print() and input() in order to improve the user experience of our Python programs.
#
# As you know, the print() function in Python is used to output a message on screen, whereas the input() instruction displays a message/question on screen and retrieves a user input that the user will type using their keyboard.

# %% [markdown]
# ![resim.png](attachment:2eed97cc-c47e-4262-b666-01ab7f50f093.png)

# %% [markdown]
# Our aim is to improve the display of text on the screen by adding a typing effect/delay.
#
# To do so we will need to import two libraries: time and sys. We will then create two new functions called typingPrint() and typingInput() as follows:

# %% [markdown]
# ``` python
# import time,sys
#
# def typingPrint(text):
#   for character in text:
#     sys.stdout.write(character)
#     sys.stdout.flush()
#     time.sleep(0.05)
#
# def typingInput(text):
#   for character in text:
#     sys.stdout.write(character)
#     sys.stdout.flush()
#     time.sleep(0.05)
#   value = input()
#   return value
#
# ```

# %% [markdown]
# We will then be able to use these two functions in our program instead of the usual print() and input() functions.
#
# Finally, to improve the user experience further, we have also created a clearScreen() function which relies on importing the os library. This function can be used at anytime to clear the screen from previous outputs and inputs. It’s ideal when creating menu based systems, splash screens, quiz based games, two player games and so on… Here is the code for our clearScreen() subroutine.

# %% [markdown]
# ``` python
# import os
#
# def clearScreen():
#   os.system("clear")
# ```

# %% [markdown]
# ## **My Solution**

# %%
# Use typingPrint() & typingInput() funcs as well as clearScreen()
# and design an interactive user panel!

# import external libs
import os, sys, time

from IPython.display import clear_output

# declare typingPrint() function
def typingPrint(text):
    for char in text: # loop for # of characters in the string
        sys.stdout.write(char) # print the character
        sys.stdout.flush() # force string buffer to print directly
        time.sleep(0.05) # wait for 0.05 sec after printing character
    # end of for
# end of function

# declare typingInput() function
def typingInput(text):
    for char in text: # loop for # of characters in the string
        sys.stdout.write(char) # print the character 
        sys.stdout.flush() # force string buffer to print directly
        time.sleep(0.05) # wait for 0.05 sec after printing character
    # end of for
    value = input() # ask for user input
    return value # return input string
# end of function

# declare clearScreen() function
def clearScreen():
    for i in range(10):
        clear_output(wait=True) # clear the screen in JupyterLab :)
        print(" ")
        
    # os.system("clear") -> console based?
    
# ask for user input to enter hacker screen mode: Y -> yes, N -> No, any other -> quit. Both uppercase and lowercase
answer = typingInput("Do you want to enter the Hacker's screen mode? Y or N") 

if answer.upper() == 'Y': # if answer is Yes:
    
    # print some Python code with typing effect to mimic the Hackers Screen Mode. Code is from _7_commutersPuzzle
    
    typingPrint("DISTANCE_OXFORD_LONDON  = 60 # 60 miles from oxford to london and vice versa.\n" +
                "DISTANCE_EARTH_MOON     = 383400 # 383400 kms from earth to moon and vice versa. \n" +
                "MILE_TO_KM              = 1.609 # 1 mile is 1.609 km\n" +
                "NUMBER_OF_WORKING_DAYS  = 5 # 5 workdays in a week\n" +
                "NUMBER_OF_WORKING_WEEKS = 52 # 52 workweeks in a year\n" +
                "dailyCommute    = 2*DISTANCE_OXFORD_LONDON # arrival to work and return to home [mile]\n" +
                "weeklyCommute   = dailyCommute*NUMBER_OF_WORKING_DAYS # total commute in a week [mile]\n" +
                "yearlyCommute   = weeklyCommute*NUMBER_OF_WORKING_WEEKS # total commute in a year [mile]\n" +
                "yearlyCommuteKm = yearlyCommute*MILE_TO_KM # total commute in a year [km]\n" +
                "moonTrip        = 2*DISTANCE_EARTH_MOON # total kms from earth to moon to earth back\n" +
                "howManyYears    = moonTrip/yearlyCommuteKm # how many years needed to the moon and back!\n" +
                "print(Yuri would have travelled the equivalent of going to the Moon and back in \n" + 
                "+ str(int(howManyYears)) +  years and  + str(int((howManyYears%1)*12)) +  months and \n" +
                "+ str(round((((howManyYears%1)*12)%1)*30)) +  days!)"
                )
    
    time.sleep(1)
    
elif answer.upper() == 'N':
    
    typingPrint("Continue on normal mode!")
    
    time.sleep(1)

    
else:
    
    typingPrint("Wrong Choice!")
    
    time.sleep(1)

# end of if

# self - destroy the screen :)

typingPrint("\n\nScreen is being deleted in ... \n")
time.sleep(1)
typingPrint("5 ..... \n")
time.sleep(5)
typingPrint("4 .... \n")
time.sleep(4)
typingPrint("3 ... \n")
time.sleep(3)
typingPrint("2 .. \n")
time.sleep(2)
typingPrint("1 . \n")
time.sleep(1)

clearScreen()
# Out:
# Do you want to enter the Hacker's screen mode? Y or N
#  y
# DISTANCE_OXFORD_LONDON  = 60 # 60 miles from oxford to london and vice versa.
# DISTANCE_EARTH_MOON     = 383400 # 383400 kms from earth to moon and vice versa.
# MILE_TO_KM              = 1.609 # 1 mile is 1.609 km
# NUMBER_OF_WORKING_DAYS  = 5 # 5 workdays in a week
# NUMBER_OF_WORKING_WEEKS = 52 # 52 workweeks in a year
# dailyCommute    = 2*DISTANCE_OXFORD_LONDON # arrival to work and return to home [mile]
# weeklyCommute   = dailyCommute*NUMBER_OF_WORKING_DAYS # total commute in a week [mile]
# yearlyCommute   = weeklyCommute*NUMBER_OF_WORKING_WEEKS # total commute in a year [mile]
# yearlyCommuteKm = yearlyCommute*MILE_TO_KM # total commute in a year [km]
# moonTrip        = 2*DISTANCE_EARTH_MOON # total kms from earth to moon to earth back
# howManyYears    = moonTrip/yearlyCommuteKm # how many years needed to the moon and back!
# print(Yuri would have travelled the equivalent of going to the Moon and back in
# ...
