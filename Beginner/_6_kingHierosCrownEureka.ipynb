# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AzizKABA/pythonCodeChallenges/blob/main/_6_kingHierosCrownEureka.ipynb)

# %% [markdown]
# # Python Code Challenges
#
# Challenge Question Source: 101computing.net
#
# Level: Beginner
#
# Solutions: by Aziz KABA
#
# TimeStamp : 13/08/2022
# 21:46

# %% [markdown]
# ## **Eureka! (and King Hiero’s Crown)**

# %% [markdown]
# ## **Did you know?**

# %% [markdown]
# Archimedes is one of the most famous physicist, mathematician, astronomer and inventor of the classical age: He lived in Syracuse on the island of Sicily in the third century B.C. Many of his inventions and theories are still being used today.
#
# This Python challenge will be based on Archimedes’ most famous “Eureka!” moment: At the time, Hiero, The King of Syracuse (Sicily, Italy), had given his goldsmith some pure gold and asked him to make a crown out of this gold. On reception of the crown, Hiero suspected he had been cheated by the goldsmith. He believe the goldsmith had replaced some of the pure gold with the same weight of silver. However Hiero needed to be able to prove that his suspicion was correct and that the crown was not made of pure gold.

# %% [markdown]
# ![resim.png](attachment:7add5f5c-3c26-4382-9433-4f8a3ceaca2b.png)

# %% [markdown]
# Knowing the weight/mass of the crown was not enough to confirm whether the crown was made of pure gold (as opposed to a mix of gold and silver). However if Archimedes knew that if he could accurately measure the volume of the crown, he could work out its density. (Density = mass / volume). He could then compare this density with the density of pure gold to see if they are the same. If not, this would be the proof that the crown is not just made of pure gold which would confirm Hiero’s suspicion. The issue was that, though it was easy at the time to precisely measure the mass of an object, there was no method for working out the exact volume of an irregular object (such as a crown!).
#
# It’s while stepping into a bath that Archimedes noticed that the water level rose: he immediately deducted that the volume of water displaced must be equal to the volume of the part of his body he had submerged. He then realised that the volume of irregular objects could be measured with precision using this submersion approach. He is said to have been so eager to share his discovery that he leapt out of his bathtub and ran naked through the streets of Syracuse shouting Eureka! Eureka! (Greek for “I have it!”).

# %% [markdown]
# ![resim.png](attachment:8dc9bc94-23e9-4dda-af69-52a455fbe645.png)

# %% [markdown]
# By applying this approach to the golden crown, Archimedes was able to get an accurate measure of the volume of the crown and could hence calculate the density of the crown which effectively turned out to be of a lesser density than pure gold. This confirmed Hiero’s suspicion that his goldsmith had stolen some of the pure gold he was given to make this crown!

# %% [markdown]
# ## **Python Challenge**

# %% [markdown]
# In this Python challenge we will use a program to help identify the density of an object and compare with the known density of different metals such as gold, silver, bronze, etc.
#
# Our algorithm will:
#
#     Ask the user to enter the mass of an object. (in Kg)
#     Ask the user to enter the volume of an object. (in m3)
#     Calculate and output the density of this object (mass/volume)
#     Compare this density with the densities of different metals such as pure gold, silver and bronze and output the corresponding metal if there is a match.
#
# Our algorithm will use the following data:

# %% [markdown]
# Metal&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Density
#
#
# Aluminium&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Between 2400 kg/m3 and 2700 kg/m3
#
#
# Bronze&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Between 8100 kg/m3 and 8300 kg/m3
#
#
# Silver&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 	    Between 10400 kg/m3 and 10600 kg/m3
#
# Lead&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 	    Between 11200 kg/m3 and 11400 kg/m3
#
# Gold &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;	    Between 17100 kg/m3 and 17500 kg/m3
#
# Platinum&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;	Between 21000 kg/m3 and 21500 kg/m3

# %% [markdown]
# ## **Your Challenge**

# %% [markdown]
# Complete the code below and use your code to work out what the following four crowns are made of…

# %% [markdown]
# |  # | Object   |  Input Values
#
#
# |  1 |![resim.png](attachment:9fd09bd6-418a-4f23-a7ba-4d1ef8eec088.png)|  Mass:0.567kg
# Volume: 54cm3 = 0.000054m3|
#
#
# |  2 |![resim.png](attachment:733a17de-7bc4-4f1e-a1ab-88bfff9a4784.png)|Mass:1.213kg
# Volume: 70cm3 = 0.00007m3|
#
#
# |  3 |![resim.png](attachment:f2e27c16-e2ab-420b-aa1e-51de35527e13.png)| Mass:0.731kg
# Volume: 65cm3 = 0.000065m3|
#
#
# |  4 |![resim.png](attachment:34703f7b-c628-4d51-bdd9-92b844883c94.png)| Mass:0.585kg
# Volume: 71cm3 = 0.000071m3|

# %% [markdown]
# ## **My Solution**

# %%
# EUREKA!

# define the constants
# lowest and highest density values of known metals
# unit in [kg/m3]

ALUMINIUM_LOW_DENSITY = 2400
ALUMINIUM_HIGH_DENSITY = 2700
BRONZE_LOW_DENSITY = 8100
BRONZE_HIGH_DENSITY = 8300
SILVER_LOW_DENSITY = 10400
SILVER_HIGH_DENSITY = 10600
LEAD_LOW_DENSITY = 11200
LEAD_HIGH_DENSITY = 11400
GOLD_LOW_DENSITY = 17100
GOLD_HIGH_DENSITY = 17500
PLATINUM_LOW_DENSITY = 21000
PLATINUM_HIGH_DENSITY = 21500

# determine the type of the test object. Reserved for future code integrations.

ALUMINIUM = 1
BRONZE = 2
SILVER = 3
LEAD = 4
GOLD = 5
PLATINUM = 6
NONE = 7

# user input section

massInput = float(input("Please enter the mass of the test object: [kg]")) # take mass as float

volumeInput = float(input("Please enter the volume of the test object: [m3]")) # take volume as float

densityValue = float(massInput/volumeInput) # calculate density and make sure its float
 
print("Density of the test object is " + str(densityValue) + " [kg/m3]") # show calculated density to the user

if densityValue >= ALUMINIUM_LOW_DENSITY and densityValue <= ALUMINIUM_HIGH_DENSITY:
    objectType = ALUMINIUM
    print("Type of the test object is: ALUMINIUM")
elif densityValue >= BRONZE_LOW_DENSITY and densityValue <= BRONZE_HIGH_DENSITY:
    objectType = BRONZE
    print("Type of the test object is: BRONZE")
elif densityValue >= SILVER_LOW_DENSITY and densityValue <= SILVER_HIGH_DENSITY:
    objectType = SILVER
    print("Type of the test object is: SILVER")
elif densityValue >= LEAD_LOW_DENSITY and densityValue <= LEAD_HIGH_DENSITY:
    objectType = LEAD
    print("Type of the test object is: LEAD")
elif densityValue >= GOLD_LOW_DENSITY and densityValue <= GOLD_HIGH_DENSITY:
    objectType = GOLD
    print("Type of the test object is: GOLD")
elif densityValue >= PLATINUM_LOW_DENSITY and densityValue <= PLATINUM_HIGH_DENSITY:
    objectType = PLATINUM
    print("Type of the test object is: PLATINUM")
else:
    objectType = NONE
    print("Type of the test object is: NONE")
  # end if

# end code

# %% [markdown]
# ### *TEST OUTPUT 1:*

# %% [markdown]
# ![resim.png](attachment:c319577a-64eb-4523-9baa-1086bde035ac.png)

# %% [markdown]
# ### *TEST OUTPUT 2:*

# %% [markdown]
# ![resim.png](attachment:2e6a0a2b-4b28-43b5-9326-857494a51c0e.png)

# %% [markdown]
# ### *TEST OUTPUT 3:*

# %% [markdown]
# ![resim.png](attachment:b806b75b-20d9-47a8-b023-5598d014c199.png)

# %% [markdown]
# ### *TEST OUTPUT 4:*

# %% [markdown]
# ![resim.png](attachment:def872ef-48bc-4a10-8435-0c15732f4ff7.png)
