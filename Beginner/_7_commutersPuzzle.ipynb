# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AzizKABA/pythonCodeChallenges/blob/main/Beginner/_7_commutersPuzzle.ipynb)

# %% [markdown]
# # Python Code Challenges
#
# Challenge Question Source: 101computing.net
#
# Level: Beginner
#
# Solutions: by Aziz KABA
#
# TimeStamp : 15/08/2022
# 20:49

# %% [markdown]
# ## **The commuter’s puzzle**

# %% [markdown]
# Yuri lives in Oxford, UK and commutes by train to his work place in London every working day of the week (5 days a week).
#
# One evening, Yuri spot the Moon through the train window and asked himself the following question:
#
# “In how many years will I have travelled the equivalent distance of going to the Moon and back due to my daily commute?”

# %% [markdown]
# ![resim.png](attachment:2a5794ea-f396-4542-a7d5-85b153e72d70.png)

# %% [markdown]
# On a piece of paper Yuri has gathered some data needed to answer this question:

# %% [markdown]
# Description &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;Value
#
#
# Distance between Oxford and London: &emsp;&emsp;&emsp;&emsp;&emsp;60 miles
#
#
# Distance between planet Earth and the Moon: &emsp;&ensp;383,400km
#
#
# Number of km in 1 mile: 	&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;1.609km
#
#
# Number of working days per week: 	&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;5
#
#
# Number of weeks in a year: 	&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp;52

# %% [markdown]
# He has also drawn the following flowchart to help him find the answer. His intention was to then use some Python code to implement this flowchart and work out the answer to his question. This algorithm is a sequencing algorithm based on the following steps:
#
#     1. Work out the total distance travelled over a year (in km).
#     2. Work out the distance of a return journey to the Moon (in km).
#     3. The number of years can be calculated by dividing the distance of a return journey to the Moon by the total distance travelled over a year.

# %% [markdown]
# ![resim.png](attachment:abac8187-38ce-4199-9942-1c105a947c2e.png)

# %% [markdown]
# **Python Code**
#
# You can use the above flowchart to complete the Python code for this sequencing algorithm.

# %% [markdown]
# ## **My Solution**

# %%
# DAILY COMMUTE TO THE MOON!

# Bonus: Year & Month & Day decode

# constant values for the trip calculation

DISTANCE_OXFORD_LONDON  = 60 # 60 miles from oxford to london and vice versa.
DISTANCE_EARTH_MOON     = 383400 # 383400 kms from earth to moon and vice vera.
MILE_TO_KM              = 1.609 # 1 mile is 1.609 km
NUMBER_OF_WORKING_DAYS  = 5 # 5 workdays in a week
NUMBER_OF_WORKING_WEEKS = 52 # 52 workweeks in a year

# calculate the values

dailyCommute    = 2*DISTANCE_OXFORD_LONDON # arrival to work and return to home [mile]
weeklyCommute   = dailyCommute*NUMBER_OF_WORKING_DAYS # total commute in a week [mile]
yearlyCommute   = weeklyCommute*NUMBER_OF_WORKING_WEEKS # total commute in a year [mile]
yearlyCommuteKm = yearlyCommute*MILE_TO_KM # total commute in a year [km]
moonTrip        = 2*DISTANCE_EARTH_MOON # total kms from earth to moon to earth back

howManyYears    = moonTrip/yearlyCommuteKm # how many years needed to the moon and back!

print("Yuri would have travelled the equivalent of going to the Moon and back in " 
      + str(int(howManyYears)) + " years and " + str(int((howManyYears%1)*12)) + " months and "
      + str(round((((howManyYears%1)*12)%1)*30)) + " days!")
# Out:
# Yuri would have travelled the equivalent of going to the Moon and back in 15 years and 3 months and 9 days!
